# %%
top5 = ["Israr Ahmed", "Noman Ali", "Tuaha", "Abu Saad", "Yasmin"]  #mytop5 personalities  

print(top5)
# Out:
# ['Israr Ahmed', 'Noman Ali', 'Tuaha', 'Abu Saad', 'Yasmin']

# %%
print("Total:", len(top5))
# Out:
# Total: 5

# %%
top5 = ["Israr Ahmed", "Noman Ali", "Tuaha", "Abu Saad", "Yasmin"]
for name in top5:
    print(name, "-")
# Out:
# Israr Ahmed -
# Noman Ali -
# Tuaha -
# Abu Saad -
# Yasmin -

# %%
top5 = ["Israr Ahmed", "Noman Ali", "Tuaha", "Abu Saad", "Yasmin"]
print(top5)
print(top5[0])
print("0 index",top5[0])
print("-1 index",top5[-1])
# Out:
# ['Israr Ahmed', 'Noman Ali', 'Tuaha', 'Abu Saad', 'Yasmin']
# Israr Ahmed
# 0 index Israr Ahmed
# -1 index Yasmin

# %%
top5.sort()                 # sorts the list itself (A-Z)
print(top5)
# Out:
# ['Abu Saad', 'Israr Ahmed', 'Noman Ali', 'Tuaha', 'Yasmin']

# %%
top5 = ["Israr Ahmed", "Noman Ali", "Tuaha", "Abu Saad", "Yasmin"]
top5.append("Sheikh Hamza")        # add to the end
print(top5)
# Out:
# ['Israr Ahmed', 'Noman Ali', 'Tuaha', 'Abu Saad', 'Yasmin', 'Sheikh Hamza']

# %%
top5 = ["Israr Ahmed", "Noman Ali", "Tuaha", "Abu Saad", "Yasmin", "Sheikh Hamza"]   
top5.remove("Noman Ali")        # remove by value    
print (top5)
# Out:
# ['Israr Ahmed', 'Tuaha', 'Abu Saad', 'Yasmin', 'Sheikh Hamza']

# %%
my_info = ("Nabiha", "Hyderabad")
for item in my_info:
    print(item)
# Out:
# Nabiha
# Hyderabad

# %%
subjects = ["Math", "English", "Science", "Urdu"]
subjects.sort()                 # sorts the list itself (A-Z)
print(subjects)
# Out:
# ['English', 'Math', 'Science', 'Urdu']

# %%
marks = [85, 78, 92, 88]

for mark in marks:
    print(mark)
# Out:
# 85
# 78
# 92
# 88

# %%
print("Total:", len(marks))
# Out:
# Total: 4

# %%
marks.sort()                 # sorts the list itself (A-Z)
print(marks)
# Out:
# [78, 85, 88, 92]
